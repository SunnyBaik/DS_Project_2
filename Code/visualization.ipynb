# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = '/Users/jonghyunchoe/Documents/Others/GitHub/DS_Project_2/CSV/'
predicted_train = pd.read_csv(path + 'predicted_train.csv')
model_predicted_train = pd.read_csv(path + 'model_predicted_train.csv')
predicted_test = pd.read_csv(path + 'predicted_test.csv')
window_predicted_test = pd.read_csv(path + 'window_predicted_test.csv')
window_predicted_train = pd.read_csv(path + 'window_predicted_train.csv')
window_average_predicted_test = pd.read_csv(path + 'window_average_predicted_test.csv')
window_interval_predicted_test = pd.read_csv(path + 'window_interval_predicted_test.csv')
window_sensor_pushed = pd.read_csv(path + 'window_sensor_pushed.csv')
box_window_predicted_train = pd.read_csv(path + 'box_window_predicted_train.csv')

# %%
# plot의 사이즈를 지정하는 코드로  원하는 사이즈로 설정하면 됩니다.
plt.rcParams["figure.figsize"] = (18,5) 

def plot_time(df, time=(0, 100), columns='all'):
    df_time = df[(df['time']>=time[0]) & (df['time']<time[1])]
    column_list = df.columns if columns=='all' else columns

    for col in column_list:
        if col !='time':
            plt.plot('time', col, data=df_time)

    plt.legend(loc='center left', bbox_to_anchor=(1.02, 0.5))
    plt.show()

# %%
# plot_time(train, time=(100, 500))
predicted_train['time'] = predicted_train.index/100
plot_time(predicted_train, time=(2000, 3000), columns=['s1', 'label', 'predicted_label'])

# %%
model_predicted_train['time'] = model_predicted_train.index/100
plot_time(model_predicted_train, time=(0, 10000), columns=['s1', 'label', 'predicted_label'])

# %%
predicted_test['time'] = predicted_test.index/100
plot_time(predicted_test, time=(0,80000), columns=['label'])

# %%
window_predicted_test['time'] = window_predicted_test.index/100
plot_time(window_predicted_test, time=(3000,4000), columns=['label'])

# %%
window_average_predicted_test['time'] = window_average_predicted_test.index/100
plot_time(window_average_predicted_test, time=(0,1000), columns=['label'])

# %%
window_interval_predicted_test['time'] = window_predicted_test.index/100
plot_time(window_interval_predicted_test, time=(0,1000), columns=['label'])

# %%
predicted_train['time'] = predicted_train.index/100
plot_time(predicted_train, time=(0, 3000), columns=['label', 's1', 'predicted_label'])
window_sensor_pushed['time'] = window_sensor_pushed.index/2
plot_time(window_sensor_pushed, time=(0,3000), columns=['label', 't21'])

# %%
window_predicted_train['time'] = window_predicted_train.index/100
plot_time(window_predicted_train, time=(3000,4500), columns=['label', 's1', 'predicted_label'])

# %%
box_window_predicted_train = pd.read_csv(path + 'box_window_predicted_train.csv')
box_window_predicted_train['time'] = box_window_predicted_train.index/100
plot_time(box_window_predicted_train, time=(3000,5000), columns=['label', 'predicted_label_box'])
